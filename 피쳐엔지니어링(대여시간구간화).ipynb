# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# # 데이터 불러오기

# %%
preprocessed_data = pd.read_pickle('drive/MyDrive/아이펠_해커톤/hackathon_data/ggd2030_preprocessed.pkl')
preprocessed_data.head()

# %%
preprocessed_df = preprocessed_data.copy()

# %% [markdown]
# # Feature Engineering(대여시간구간화)

# %%
preprocessed_df['대여시간구간화'] = 0


# 평일 1구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(7,9)) & 
                                             (preprocessed_df[컬럼13.index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_1구간_초단시간'


binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(7,9)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_1구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(7,9)) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_1구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(7,9)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_1구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(7,9)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_1구간_초장시간'



# 평일 2구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(10,12)) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_2구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(10,12)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_2구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(10,12)) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_2구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(10,12)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_2구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(10,12)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_2구간_초장시간'



# 평일 3구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(13,16)) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_3구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(13,16)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_3구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(13,16)) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_3구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(13,16)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_3구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(13,16)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_3구간_초장시간'



# 평일 4구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(17,19)) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_4구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(17,19)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_4구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(17,19)) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_4구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(17,19)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_4구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(17,19)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_4구간_초장시간'



# 평일 5구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(20,22)) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_5구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(20,22)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_5구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(20,22)) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_5구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(20,22)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_5구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(20,22)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_5구간_초장시간'



# 평일 6구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             ((preprocessed_df['컬럼13']==0) | (preprocessed_df['컬럼13']==1) | (preprocessed_df['컬럼13']==23)) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_6구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             ((preprocessed_df['컬럼13']==0) | (preprocessed_df['컬럼13']==1) | (preprocessed_df['컬럼13']==23)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_6구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             ((preprocessed_df['컬럼13']==0) | (preprocessed_df['컬럼13']==1) | (preprocessed_df['컬럼13']==23)) & 
                                             (preprocessed_df['컬럼13'] >=4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_6구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             ((preprocessed_df['컬럼13']==0) | (preprocessed_df['컬럼13']==1) | (preprocessed_df['컬럼13']==23)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_6구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             ((preprocessed_df['컬럼13']==0) | (preprocessed_df['컬럼13']==1) | (preprocessed_df['컬럼13']==23)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_6구간_초장시간'



# 평일 7구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(2,6)) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_7구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(2,6)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_7구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(2,6)) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_7구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(2,6)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_7구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(2,6)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '평일_7구간_초장시간'



# 주말 1구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(7,9)) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_1구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(7,9)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_1구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(7,9)) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_1구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(7,9)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_1구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(7,9)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_1구간_초장시간'



# 주말 2구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(10,14)) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_2구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(10,14)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_2구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(10,14)) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_2구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(10,14)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_2구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(10,14)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_2구간_초장시간'



# 주말 3구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(15,17)) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_3구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(15,17)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_3구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(15,17)) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_3구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(15,17)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_3구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(15,17)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_3구간_초장시간'



# 주말 4구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(18,22)) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_4구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(18,22)) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_4구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(18,22)) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_4구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(18,22)) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_4구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(18,22)) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_4구간_초장시간'



# 주말 5구간
binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             ((preprocessed_df['컬럼13']==23) | (preprocessed_df['컬럼13'].between(0,6))) & 
                                             (preprocessed_df['컬럼13']<2)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_5구간_초단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             ((preprocessed_df['컬럼13']==23) | (preprocessed_df['컬럼13'].between(0,6))) & 
                                             (preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_5구간_단시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             ((preprocessed_df['컬럼13']==23) | (preprocessed_df['컬럼13'].between(0,6))) & 
                                             (preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_5구간_중시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             ((preprocessed_df['컬럼13']==23) | (preprocessed_df['컬럼13'].between(0,6))) & 
                                             (preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_5구간_장시간'

binning_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             ((preprocessed_df['컬럼13']==23) | (preprocessed_df['컬럼13'].between(0,6))) & 
                                             (preprocessed_df['컬럼13'] >= 17)].index)
for i in binning_list:
  preprocessed_df.loc[i,'대여시간구간화'] = '주말_5구간_초장시간'   

preprocessed_df['대여시간구간화'].nunique()
# Out:
# 60

# %% [markdown]
# # Feature Engineering(`컬럼13`)

# %%
preprocessed_df['컬럼13_bin'] = 0


# 평일 1구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                       (preprocessed_df['컬럼13'].between(7,9))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '평일_1구간'



# 평일 2구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(10,12))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '평일_2구간'



# 평일 3구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(13,16))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '평일_3구간'



# 평일 4구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(17,19))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '평일_4구간'



# 평일 5구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(20,22))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '평일_5구간'



# 평일 6구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             ((preprocessed_df['컬럼13']==0) | (preprocessed_df['컬럼13']==1) | (preprocessed_df['컬럼13']==23))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '평일_6구간'



# 평일 7구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==0) & 
                                             (preprocessed_df['컬럼13'].between(2,6))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '평일_7구간'



# 주말 1구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(7,9))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '주말_1구간'



# 주말 2구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(10,14))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '주말_2구간'



# 주말 3구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(15,17))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '주말_3구간'



# 주말 4구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             (preprocessed_df['컬럼13'].between(18,22))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '주말_4구간'



# 주말 5구간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼17']==1) & 
                                             ((preprocessed_df['컬럼13']==23) | (preprocessed_df['컬럼13'].between(0,6)))].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '주말_5구간'



preprocessed_df['대여시간구간화'].nunique()
# Out:
# 60

# %% [markdown]
# # Feature Engineering(`컬럼13`)

# %%
preprocessed_df['컬럼13_bin'] = 0

# 초단시간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼13']<2)].index)

for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '초단시간'


# 단시간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼13'] >= 2) &
                                             (preprocessed_df['컬럼13'] < 4)].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '단시간'


# 중시간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼13'] >= 4) &
                                             (preprocessed_df['컬럼13'] < 7)].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '중시간'


# 장시간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼13'] >= 7) &
                                             (preprocessed_df['컬럼13'] < 17)].index)
for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '장시간'


# 초장시간
컬럼13_list = list(preprocessed_df[(preprocessed_df['컬럼13'] >= 17)].index)

for i in 컬럼13_list:
  preprocessed_df.loc[i,'컬럼13_bin'] = '초장시간'   

preprocessed_df['컬럼13_bin'].nunique()
# Out:
# 5

# %%
preprocessed_df.to_pickle('drive/MyDrive/아이펠_해커톤/hackathon_data/대여시간구간화_60.pkl')

# %%
preprocessed_df = pd.read_pickle('drive/MyDrive/아이펠_해커톤/hackathon_data/대여시간구간화_60.pkl')

# %%
preprocessed_df

# %% [markdown]
# # Cluster별 EDA

# %%
preprocessed_df['Cluster_num']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 297753    3
# 297754    3
# 297755    3
# 297756    3
# 297757    3
# Name: Cluster_num, Length: 297758, dtype: int64

# %% [markdown]
# ## Cluster별 대여시간 구간화

# %%
Cluster_list = np.arange(0,4)

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(15, 60))

for row in range(4):
        idx = row 
        
        if idx < len(Cluster_list):
            ax = axes[row]
            Cluster = Cluster_list[idx]
            sns.barplot(x=preprocessed_df[preprocessed_df['Cluster_num']==Cluster].groupby('대여시간구간화').size(), 
                        y=preprocessed_df[preprocessed_df['Cluster_num']==Cluster].groupby('대여시간구간화').size().index, 
                        palette='Blues_d',
                        ax=ax)
            ax.set(xlabel=Cluster)

# %%
Cluster_list = np.arange(0,4)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 15))

for row in range(2):
    for col in range(2):
        idx = row * 2 + col
        
        if idx < len(Cluster_list):
            ax = axes[row][col]
            Cluster = Cluster_list[idx]
            sns.barplot(x=preprocessed_df[preprocessed_df['Cluster_num']==Cluster].groupby('컬럼13_bin').size(), 
                        y=preprocessed_df[preprocessed_df['Cluster_num']==Cluster].groupby('컬럼13_bin').size().index, 
                        palette='Blues_d',
                        ax=ax)
            ax.set(xlabel=Cluster)

# %%
Cluster_list = np.arange(0,4)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 15))

for row in range(2):
    for col in range(2):
        idx = row * 2 + col
        
        if idx < len(Cluster_list):
            ax = axes[row][col]
            Cluster = Cluster_list[idx]
            sns.barplot(x=preprocessed_df[preprocessed_df['Cluster_num']==Cluster].groupby('컬럼13_bin').size(), 
                        y=preprocessed_df[preprocessed_df['Cluster_num']==Cluster].groupby('컬럼13_bin').size().index, 
                        palette='Blues_d',
                        ax=ax)
            ax.set(xlabel=Cluster)

# %% [markdown]
# ## Cluster별 TOP5 대여시간

# %%
Cluster_top5 = pd.pivot_table(preprocessed_df, index='Cluster_num', columns='대여시간구간화', values='컬럼7func='count', fill_value=0)
Cluster_top5

c = ['1st Max','2nd Max','3rd Max','4th Max','5th Max','6th Max','7th Max','8th Max','9th Max','10th Max']

Cluster_top5 = (Cluster_top5
                .apply(lambda x: pd.Series(x.nlargest(10).index, index=c), axis=1)
                .reset_index())
Cluster_top5
# Out:
#    Cluster_num      1st Max      2nd Max     3rd Max     4th Max     5th Max  \
# 0            0   주말_2구간_중시간  평일_5구간_초단시간  주말_2구간_장시간  평일_3구간_중시간  평일_3구간_단시간
# 1            1  평일_5구간_초단시간   주말_2구간_중시간  평일_3구간_단시간  평일_3구간_중시간  평일_4구간_단시간
# 2            2  평일_5구간_초단시간   평일_3구간_단시간  주말_2구간_중시간  평일_3구간_중시간  평일_4구간_단시간
# 3            3  평일_5구간_초단시간   주말_2구간_중시간  평일_3구간_단시간  평일_3구간_중시간  평일_4구간_단시간
#
#       6th Max      7th Max      8th Max      9th Max     10th Max
# 0  평일_5구간_단시간   평일_4구간_단시간   주말_4구간_단시간   주말_2구간_단시간  주말_4구간_초단시간
# 1  평일_5구간_단시간   주말_2구간_장시간  평일_6구간_초단시간  주말_4구간_초단시간   평일_2구간_중시간
# 2  평일_5구간_단시간  평일_3구간_초단시간   주말_2구간_장시간  주말_4구간_초단시간   평일_4구간_중시간
# 3  평일_5구간_단시간  평일_6구간_초단시간  평일_3구간_초단시간   주말_4구간_단시간   평일_4구간_중시간

# %%
Cluster_top5 = pd.pivot_table(preprocessed_df, index='Cluster_num', columns='컬럼13_bin', values='컬럼7', aggfunc='count', fill_value=0)
Cluster_top5
Cluster_top5 = Cluster_top5.T.div(Cluster_top5.T.sum(), axis=1, level=1)*100
Cluster_top5
# Out:
# Cluster_num              0          1          2          3
# total_hours_bin
# 단시간              24.455424  25.612281  26.504425  27.711027
# 장시간              18.751774  16.457643  15.845133  15.530690
# 중시간              22.454055  22.012541  22.263274  22.426942
# 초단시간             24.026440  26.566690  26.516593  26.739815
# 초장시간             10.312307   9.350844   8.870575   7.591526

# %%
Cluster_top5 = pd.pivot_table(preprocessed_df, index='Cluster_num', columns='컬럼13_bin', values='컬럼7', aggfunc='count', fill_value=0)
Cluster_top5

c = ['1st Max','2nd Max','3rd Max','4th Max','5th Max','6th Max','7th Max','8th Max','9th Max']

Cluster_top5 = (Cluster_top5
                .apply(lambda x: pd.Series(x.nlargest(9).index, index=c), axis=1)
                .reset_index())
Cluster_top5
# Out:
#    Cluster_num 1st Max 2nd Max 3rd Max 4th Max 5th Max 6th Max 7th Max  \
# 0            0  주말_2구간  평일_3구간  평일_4구간  평일_5구간  평일_2구간  주말_4구간  주말_3구간
# 1            1  주말_2구간  평일_3구간  평일_4구간  평일_5구간  평일_2구간  주말_4구간  평일_1구간
# 2            2  평일_3구간  주말_2구간  평일_4구간  평일_5구간  평일_2구간  주말_4구간  평일_1구간
# 3            3  평일_3구간  주말_2구간  평일_4구간  평일_5구간  평일_2구간  주말_4구간  주말_3구간
#
#   8th Max 9th Max
# 0  평일_1구간  평일_6구간
# 1  주말_3구간  평일_6구간
# 2  주말_3구간  평일_6구간
# 3  평일_1구간  평일_6구간

# %%
Cluster_top5 = pd.pivot_table(preprocessed_df, index='Cluster_num', columns='컬럼13_bin', values='컬럼7', aggfunc='count', fill_value=0)
Cluster_top5

c = ['1st Max','2nd Max','3rd Max','4th Max']

Cluster_top5 = (Cluster_top5
                .apply(lambda x: pd.Series(x.nlargest(4).index, index=c), axis=1)
                .reset_index())
Cluster_top5
# Out:
#    Cluster_num 1st Max 2nd Max 3rd Max 4th Max
# 0            0     단시간    초단시간     중시간     장시간
# 1            1    초단시간     단시간     중시간     장시간
# 2            2    초단시간     단시간     중시간     장시간
# 3            3     단시간    초단시간     중시간     장시간
